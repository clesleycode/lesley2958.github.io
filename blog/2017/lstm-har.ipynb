# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

time_points = np.linspace(0, 8*np.pi, 8000)

seq_length = 5
dataX = []
dataY = []
for i in range(0, len(time_points) - seq_length, 1):
    seq_in = np.sin(time_points)[i:i + seq_length]
    seq_out = np.cos(time_points)[i]
    dataX.append([seq_in])
    dataY.append(seq_out)

X = np.reshape(dataX, (len(dataX), seq_length, 1))
y = np.reshape(dataY, (len(dataY), 1))

# %%
model = Sequential()
model.add(LSTM(32, input_shape=(X.shape[1], X.shape[2])))


model.add(Dense(y.shape[1], activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X[:6000], y[:6000], epochs=200, batch_size=10, verbose=2, validation_split=0.3)
# Out:
# Train on 4200 samples, validate on 1800 samples
# Epoch 1/200
#  - 3s - loss: 0.5163 - val_loss: 0.4790
# Epoch 2/200
#  - 2s - loss: 0.5150 - val_loss: 0.4847
# Epoch 3/200
#  - 2s - loss: 0.5146 - val_loss: 0.4820
# Epoch 4/200
#  - 2s - loss: 0.5140 - val_loss: 0.4849
# Epoch 5/200
#  - 2s - loss: 0.5135 - val_loss: 0.4799
# Epoch 6/200
#  - 2s - loss: 0.5140 - val_loss: 0.4907
# Epoch 7/200
#  - 2s - loss: 0.5142 - val_loss: 0.4834
# Epoch 8/200
#  - 2s - loss: 0.5131 - val_loss: 0.4884
# Epoch 9/200
#  - 2s - loss: 0.5129 - val_loss: 0.4796
# Epoch 10/200
#  - 2s - loss: 0.5133 - val_loss: 0.4813
# Epoch 11/200
#  - 2s - loss: 0.5124 - val_loss: 0.4842
# Epoch 12/200
#  - 2s - loss: 0.5125 - val_loss: 0.4851
# Epoch 13/200
#  - 2s - loss: 0.5121 - val_loss: 0.4819
# Epoch 14/200
#  - 2s - loss: 0.5123 - val_loss: 0.4840
# Epoch 15/200
#  - 2s - loss: 0.5109 - val_loss: 0.4874
# Epoch 16/200
#  - 2s - loss: 0.5109 - val_loss: 0.4833
# Epoch 17/200
#  - 2s - loss: 0.5112 - val_loss: 0.4879
# Epoch 18/200
#  - 2s - loss: 0.5098 - val_loss: 0.4855
# Epoch 19/200
#  - 2s - loss: 0.5082 - val_loss: 0.4810
# Epoch 20/200
#  - 2s - loss: 0.5084 - val_loss: 0.4906
# Epoch 21/200
#  - 2s - loss: 0.5071 - val_loss: 0.4875
# Epoch 22/200
#  - 2s - loss: 0.5063 - val_loss: 0.4790
# Epoch 23/200
#  - 2s - loss: 0.5045 - val_loss: 0.4838
# Epoch 24/200
#  - 2s - loss: 0.5050 - val_loss: 0.4835
# Epoch 25/200
#  - 2s - loss: 0.5027 - val_loss: 0.4652
# Epoch 26/200
#  - 2s - loss: 0.5023 - val_loss: 0.4906
# Epoch 27/200
#  - 2s - loss: 0.5004 - val_loss: 0.4895
# Epoch 28/200
#  - 3s - loss: 0.4987 - val_loss: 0.4797
# Epoch 29/200
#  - 2s - loss: 0.4975 - val_loss: 0.4672
# Epoch 30/200
#  - 2s - loss: 0.4964 - val_loss: 0.4817
# Epoch 31/200
#  - 2s - loss: 0.4932 - val_loss: 0.4750
# Epoch 32/200
#  - 2s - loss: 0.4907 - val_loss: 0.4866
# Epoch 33/200
#  - 2s - loss: 0.4901 - val_loss: 0.5299
# Epoch 34/200
#  - 2s - loss: 0.4892 - val_loss: 0.4759
# Epoch 35/200
#  - 2s - loss: 0.4829 - val_loss: 0.5119
# Epoch 36/200
#  - 2s - loss: 0.4797 - val_loss: 0.4917
# Epoch 37/200
#  - 2s - loss: 0.4786 - val_loss: 0.4440
# Epoch 38/200
#  - 2s - loss: 0.4694 - val_loss: 0.5133
# Epoch 39/200
#  - 2s - loss: 0.4574 - val_loss: 0.5404
# Epoch 40/200
#  - 2s - loss: 0.4440 - val_loss: 0.4675
# Epoch 41/200
#  - 2s - loss: 0.4324 - val_loss: 0.3981
# Epoch 42/200
#  - 2s - loss: 0.4197 - val_loss: 0.4563
# Epoch 43/200
#  - 2s - loss: 0.4032 - val_loss: 0.3558
# Epoch 44/200
#  - 2s - loss: 0.3967 - val_loss: 0.3403
# Epoch 45/200
#  - 2s - loss: 0.3786 - val_loss: 0.3608
# Epoch 46/200
#  - 2s - loss: 0.3693 - val_loss: 0.3137
# Epoch 47/200
#  - 2s - loss: 0.3622 - val_loss: 0.4046
# Epoch 48/200
#  - 2s - loss: 0.3523 - val_loss: 0.3702
# Epoch 49/200
#  - 2s - loss: 0.3330 - val_loss: 0.2954
# Epoch 50/200
#  - 2s - loss: 0.3120 - val_loss: 0.3997
# Epoch 51/200
#  - 2s - loss: 0.3078 - val_loss: 0.2656
# Epoch 52/200
#  - 2s - loss: 0.3120 - val_loss: 0.2661
# Epoch 53/200
#  - 2s - loss: 0.2985 - val_loss: 0.3107
# Epoch 54/200
#  - 2s - loss: 0.2853 - val_loss: 0.3065
# Epoch 55/200
#  - 2s - loss: 0.2705 - val_loss: 0.2988
# Epoch 56/200
#  - 2s - loss: 0.2508 - val_loss: 0.2063
# Epoch 57/200
#  - 2s - loss: 0.2456 - val_loss: 0.2398
# Epoch 58/200
#  - 2s - loss: 0.2289 - val_loss: 0.3027
# Epoch 59/200
#  - 2s - loss: 0.2397 - val_loss: 0.4127
# Epoch 60/200
#  - 2s - loss: 0.2355 - val_loss: 0.1950
# Epoch 61/200
#  - 2s - loss: 0.2245 - val_loss: 0.2611
# Epoch 62/200
#  - 2s - loss: 0.2166 - val_loss: 0.1676
# Epoch 63/200
#  - 2s - loss: 0.1944 - val_loss: 0.2487
# Epoch 64/200
#  - 2s - loss: 0.1835 - val_loss: 0.1902
# Epoch 65/200
#  - 2s - loss: 0.1910 - val_loss: 0.1755
# Epoch 66/200
#  - 2s - loss: 0.1789 - val_loss: 0.2951
# Epoch 67/200
#  - 2s - loss: 0.1677 - val_loss: 0.2847
# Epoch 68/200
#  - 2s - loss: 0.1640 - val_loss: 0.2312
# Epoch 69/200
#  - 2s - loss: 0.1500 - val_loss: 0.1506
# Epoch 70/200
#  - 2s - loss: 0.1248 - val_loss: 0.0970
# Epoch 71/200
#  - 2s - loss: 0.1418 - val_loss: 0.1520
# Epoch 72/200
#  - 2s - loss: 0.1283 - val_loss: 0.1229
# Epoch 73/200
#  - 2s - loss: 0.1287 - val_loss: 0.1778
# Epoch 74/200
#  - 2s - loss: 0.1438 - val_loss: 0.1204
# Epoch 75/200
#  - 2s - loss: 0.1378 - val_loss: 0.1323
# Epoch 76/200
#  - 2s - loss: 0.1232 - val_loss: 0.1054
# Epoch 77/200
#  - 2s - loss: 0.1375 - val_loss: 0.2906
# Epoch 78/200
#  - 2s - loss: 0.1126 - val_loss: 0.1492
# Epoch 79/200
#  - 2s - loss: 0.1309 - val_loss: 0.1583
# Epoch 80/200
#  - 2s - loss: 0.1079 - val_loss: 0.0997
# Epoch 81/200
#  - 2s - loss: 0.1134 - val_loss: 0.1065
# Epoch 82/200
#  - 2s - loss: 0.1090 - val_loss: 0.0981
# Epoch 83/200
#  - 2s - loss: 0.1027 - val_loss: 0.1005
# Epoch 84/200
#  - 2s - loss: 0.0802 - val_loss: 0.0608
# Epoch 85/200
#  - 2s - loss: 0.1030 - val_loss: 0.0720
# Epoch 86/200
#  - 2s - loss: 0.0871 - val_loss: 0.0635
# Epoch 87/200
#  - 2s - loss: 0.0794 - val_loss: 0.0519
# Epoch 88/200
#  - 3s - loss: 0.0976 - val_loss: 0.0804
# Epoch 89/200
#  - 2s - loss: 0.0772 - val_loss: 0.1648
# Epoch 90/200
#  - 2s - loss: 0.0831 - val_loss: 0.0749
# Epoch 91/200
#  - 2s - loss: 0.0836 - val_loss: 0.0715
# Epoch 92/200
#  - 2s - loss: 0.0914 - val_loss: 0.0760
# Epoch 93/200
#  - 2s - loss: 0.1053 - val_loss: 0.1041
# Epoch 94/200
#  - 2s - loss: 0.0723 - val_loss: 0.0640
# Epoch 95/200
#  - 2s - loss: 0.0756 - val_loss: 0.0485
# Epoch 96/200
#  - 2s - loss: 0.0666 - val_loss: 0.0633
# Epoch 97/200
#  - 2s - loss: 0.0823 - val_loss: 0.0624
# Epoch 98/200
#  - 2s - loss: 0.0658 - val_loss: 0.0850
# Epoch 99/200
#  - 2s - loss: 0.0775 - val_loss: 0.0984
# Epoch 100/200
#  - 2s - loss: 0.0700 - val_loss: 0.0410
# Epoch 101/200
#  - 2s - loss: 0.0464 - val_loss: 0.0422
# Epoch 102/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-1dfaa64bdc87> in <module>()
#       5 model.add(Dense(y.shape[1], activation='linear'))
#       6 model.compile(loss='mean_squared_error', optimizer='adam')
# ----> 7 model.fit(X[:6000], y[:6000], epochs=200, batch_size=10, verbose=2, validation_split=0.3)
#
# ~/anaconda3/lib/python3.6/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     958                               initial_epoch=initial_epoch,
#     959                               steps_per_epoch=steps_per_epoch,
# --> 960                               validation_steps=validation_steps)
#     961
#     962     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1655                               initial_epoch=initial_epoch,
#    1656                               steps_per_epoch=steps_per_epoch,
# -> 1657                               validation_steps=validation_steps)
#    1658
#    1659     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1211                     batch_logs['size'] = len(batch_ids)
#    1212                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1213                     outs = f(ins_batch)
#    1214                     if not isinstance(outs, list):
#    1215                         outs = [outs]
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2355         session = get_session()
#    2356         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2357                               **self.session_kwargs)
#    2358         return updated[:len(self.outputs)]
#    2359
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
plt.plot(model.predict(X[:]))
plt.plot(y[:,0])

# %%
y.shape
# Out:
# (7995, 1)
